# %% [markdown]
# # Data Exploration

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Loading Data
# Looking at shape and size of train and test sets, column names, etc.

# %%
train = pd.read_csv("data/Train.csv", index_col="Tour_ID").sort_index()
test = pd.read_csv("data/Test.csv", index_col="Tour_ID").sort_index()
descriptions = pd.read_csv("data/VariableDefinitions.csv")

# %%
descriptions
# Out:
#               Column Name                                         Definition
# 0                      id                 Unique identifier for each tourist
# 1                 country                The country a tourist coming  from.
# 2               age_group                        The age group of a tourist.
# 3             travel_with  The relation of people a tourist travel with t...
# 4            total_female                            Total number of females
# 5              total_male                              Total number of males
# 6                 purpose                  The purpose of visiting  Tanzania
# 7           main_activity           The main activity of tourism in Tanzania
# 8            infor_source  The source of information about tourism in Tan...
# 9         tour_arrangment                The arrangment of visiting Tanzania
# 10  package_transport_int  If the tour package include international tran...
# 11   package_accomodation  If the tour package include accommodation service
# 12           package_food           If the tour package include food service
# 13   package_transport_tz  If the tour package include transport service ...
# 14    package_sightseeing    If the tour package include sightseeing service
# 15    package_guided_tour             If the tour package include tour guide
# 16      package_insurance      if the tour package include insurance service
# 17         night_mainland  Number of nights a tourist spent in Tanzania m...
# 18         night_zanzibar       Number of nights a tourist spent in Zanzibar
# 19          first_trip_tz                If it was a first  trip to Tanzania
# 20          cost_category  The range of expenditures a tourist spends in ...

# %%
print("Training set shape: ", train.shape)
train.head()
# Out:
# Training set shape:  (18506, 20)
#                                   country age_group travel_with  total_female  \
# Tour_ID
# tour_id000yfpco                   GERMANY     18-24       Alone           1.0
# tour_id000zcjd9                    ZAMBIA     25-44       Alone           0.0
# tour_id003q62x6  UNITED STATES OF AMERICA     25-44       Alone           1.0
# tour_id0071kq5v  UNITED STATES OF AMERICA       65+       Alone           0.0
# tour_id00bp42je  UNITED STATES OF AMERICA     45-64       Alone           1.0
#
#                  total_male                         purpose     main_activity  \
# Tour_ID
# tour_id000yfpco         0.0            Leisure and Holidays   Hunting Tourism
# tour_id000zcjd9         1.0                        Business   Widlife Tourism
# tour_id003q62x6         0.0                    Volunteering  Cultural Tourism
# tour_id0071kq5v         1.0  Visiting Friends and Relatives   Hunting Tourism
# tour_id00bp42je         0.0            Leisure and Holidays   Widlife Tourism
#
#                                  info_source tour_arrangement  \
# Tour_ID
# tour_id000yfpco               Radio, TV, Web      Independent
# tour_id000zcjd9           Friends, relatives      Independent
# tour_id003q62x6           Friends, relatives     Package Tour
# tour_id0071kq5v           Friends, relatives      Independent
# tour_id00bp42je  Travel agent, tour operator     Package Tour
#
#                 package_transport_int package_accomodation package_food  \
# Tour_ID
# tour_id000yfpco                    No                   No           No
# tour_id000zcjd9                    No                   No           No
# tour_id003q62x6                    No                  Yes          Yes
# tour_id0071kq5v                    No                   No           No
# tour_id00bp42je                    No                  Yes          Yes
#
#                 package_transport_tz package_sightseeing package_guided_tour  \
# Tour_ID
# tour_id000yfpco                   No                  No                  No
# tour_id000zcjd9                   No                  No                  No
# tour_id003q62x6                  Yes                 Yes                 Yes
# tour_id0071kq5v                   No                  No                  No
# tour_id00bp42je                  Yes                 Yes                 Yes
#
#                 package_insurance  night_mainland  night_zanzibar  \
# Tour_ID
# tour_id000yfpco                No              23               0
# tour_id000zcjd9                No               2               0
# tour_id003q62x6                No              10               5
# tour_id0071kq5v                No              30               0
# tour_id00bp42je                No              11               0
#
#                 first_trip_tz cost_category
# Tour_ID
# tour_id000yfpco            No    Lower Cost
# tour_id000zcjd9            No    Lower Cost
# tour_id003q62x6           Yes     High Cost
# tour_id0071kq5v            No     High Cost
# tour_id00bp42je           Yes   Higher Cost

# %%
print("Test set shape: ", test.shape)
test.head()
# Out:
# Test set shape:  (6169, 19)
#                       country age_group                   travel_with  \
# Tour_ID
# tour_id007ilexv           UAE     25-44                         Alone
# tour_id00egf960         ITALY     25-44  With Other Friends/Relatives
# tour_id00er55cs        BOSNIA     25-44                         Alone
# tour_id00ickkxa      THAILAND     25-44                         Alone
# tour_id00sz0iu4  SOUTH AFRICA     18-24                         Alone
#
#                  total_female  total_male                  purpose  \
# Tour_ID
# tour_id007ilexv           1.0         0.0     Leisure and Holidays
# tour_id00egf960           3.0         1.0     Leisure and Holidays
# tour_id00er55cs           0.0         1.0     Leisure and Holidays
# tour_id00ickkxa           0.0         1.0  Meetings and Conference
# tour_id00sz0iu4           0.0         1.0                 Business
#
#                       main_activity         info_source tour_arrangement  \
# Tour_ID
# tour_id007ilexv    Cultural Tourism      Radio, TV, Web      Independent
# tour_id00egf960    Cultural Tourism  Friends, relatives      Independent
# tour_id00er55cs     Widlife Tourism  Friends, relatives      Independent
# tour_id00ickkxa  Conference Tourism  Friends, relatives      Independent
# tour_id00sz0iu4     Widlife Tourism  Friends, relatives      Independent
#
#                 package_transport_int package_accomodation package_food  \
# Tour_ID
# tour_id007ilexv                    No                   No           No
# tour_id00egf960                    No                   No           No
# tour_id00er55cs                    No                   No           No
# tour_id00ickkxa                    No                   No           No
# tour_id00sz0iu4                    No                   No           No
#
#                 package_transport_tz package_sightseeing package_guided_tour  \
# Tour_ID
# tour_id007ilexv                   No                  No                  No
# tour_id00egf960                   No                  No                  No
# tour_id00er55cs                   No                  No                  No
# tour_id00ickkxa                   No                  No                  No
# tour_id00sz0iu4                   No                  No                  No
#
#                 package_insurance  night_mainland  night_zanzibar  \
# Tour_ID
# tour_id007ilexv                No               0               4
# tour_id00egf960                No              20               0
# tour_id00er55cs                No               4               0
# tour_id00ickkxa                No               4               0
# tour_id00sz0iu4                No               2               0
#
#                 first_trip_tz
# Tour_ID
# tour_id007ilexv           Yes
# tour_id00egf960           Yes
# tour_id00er55cs           Yes
# tour_id00ickkxa           Yes
# tour_id00sz0iu4            No

# %% [markdown]
# So we have 18506 examples in our training set, and 6169 samples in our test set.
#
# Column that we are training for is called cost_category. Column names look okay.
#
# -> Might want to replace cost_category values (string) with integers (0-5) to make later ML implementation easier. Also so that we can sort by cost as currently Normal is last aplhabetically so makes visualisation somewhat more difficult.
#
# -> Might want to split training set into a dev set that we iteratively test our model on as well? So we can reserve test set for benchmarking since there's no ability to verify accuracy without uploading onto site (as far as I'm aware).

# %%
train.dtypes
# Out:
# country                   object
# age_group                 object
# travel_with               object
# total_female             float64
# total_male               float64
# purpose                   object
# main_activity             object
# info_source               object
# tour_arrangement          object
# package_transport_int     object
# package_accomodation      object
# package_food              object
# package_transport_tz      object
# package_sightseeing       object
# package_guided_tour       object
# package_insurance         object
# night_mainland             int64
# night_zanzibar             int64
# first_trip_tz             object
# cost_category             object
# dtype: object

# %% [markdown]
# ### Data Visualisation
#
# Looking at frequency distributions for categorical variables, missing values, extreme values

# %%
#Training Set
for column in train:
    print("---------",column.upper(),"---------")
    print(train[column].value_counts(normalize=True))
# Out:
# --------- COUNTRY ---------
# UNITED STATES OF AMERICA    0.153788
# UNITED KINGDOM              0.114557
# ITALY                       0.087809
# FRANCE                      0.057495
# GERMANY                     0.052361
#                               ...
# JORDAN                      0.000054
# BARBADOS                    0.000054
# BANGLADESH                  0.000054
# CAPE VERDE                  0.000054
# DJIBOUT                     0.000054
# Name: country, Length: 131, dtype: float64
# --------- AGE_GROUP ---------
# 25-44    0.488868
# 45-64    0.305198
# 18-24    0.120069
# 65+      0.079272
# <18      0.006592
# Name: age_group, dtype: float64
# --------- TRAVEL_WITH ---------
# Alone                           0.435431
# With Spouse                     0.277781
# With Other Friends/Relatives    0.187482
# With Spouse and Children        0.068441
# With Children                   0.030865
# Name: travel_with, dtype: float64
# --------- TOTAL_FEMALE ---------
# 1.0     0.521995
# 0.0     0.332198
# 2.0     0.094682
# 3.0     0.027399
# 4.0     0.010592
# 5.0     0.004810
# 6.0     0.003243
# 7.0     0.000973
# 8.0     0.000919
# 10.0    0.000703
# 11.0    0.000486
# 9.0     0.000432
# 12.0    0.000432
# 14.0    0.000324
# 13.0    0.000162
# 15.0    0.000162
# 24.0    0.000108
# 22.0    0.000054
# 17.0    0.000054
# 26.0    0.000054
# 20.0    0.000054
# 49.0    0.000054
# 23.0    0.000054
# 19.0    0.000054
# Name: total_female, dtype: float64
# --------- TOTAL_MALE ---------
# 1.0     0.638270
# 0.0     0.234270
# 2.0     0.081135
# 3.0     0.027568
# 4.0     0.008054
# 5.0     0.003622
# 6.0     0.002973
# 7.0     0.001243
# 8.0     0.000649
# 9.0     0.000486
# 10.0    0.000486
# 13.0    0.000216
# 15.0    0.000162
# 12.0    0.000162
# 11.0    0.000162
# 17.0    0.000108
# 20.0    0.000054
# 23.0    0.000054
# 44.0    0.000054
# 40.0    0.000054
# 24.0    0.000054
# 25.0    0.000054
# 14.0    0.000054
# 58.0    0.000054
# Name: total_male, dtype: float64
# --------- PURPOSE ---------
# Leisure and Holidays              0.635199
# Visiting Friends and Relatives    0.124500
# Business                          0.124122
# Meetings and Conference           0.063709
# Volunteering                      0.023668
# Other                             0.017616
# Scientific and Academic           0.010699
# Medical                           0.000486
# Name: purpose, dtype: float64
# --------- MAIN_ACTIVITY ---------
# Widlife Tourism             0.323571
# Beach Tourism               0.225440
# Wildlife Tourism            0.123365
# Conference Tourism          0.103750
# Hunting Tourism             0.092511
# Cultural Tourism            0.078029
# Mountain Climbing           0.028585
# Business                    0.015130
# Bird Tourism                0.007781
# Diving and Sport Fishing    0.001837
# Name: main_activity, dtype: float64
# --------- INFO_SOURCE ---------
# Travel agent, tour operator        0.432562
# Friends, relatives                 0.328380
# Others                             0.073922
# Newspaper, magazines, brochures    0.070302
# Radio, TV, Web                     0.066087
# Trade fair                         0.013131
# Tanzania Mission Abroad            0.010645
# Inflight magazines                 0.004971
# Name: info_source, dtype: float64
# --------- TOUR_ARRANGEMENT ---------
# Package Tour    0.50227
# Independent     0.49773
# Name: tour_arrangement, dtype: float64
# --------- PACKAGE_TRANSPORT_INT ---------
# No     0.661299
# Yes    0.338701
# Name: package_transport_int, dtype: float64
# --------- PACKAGE_ACCOMODATION ---------
# No     0.515563
# Yes    0.484437
# Name: package_accomodation, dtype: float64
# --------- PACKAGE_FOOD ---------
# No     0.548093
# Yes    0.451907
# Name: package_food, dtype: float64
# --------- PACKAGE_TRANSPORT_TZ ---------
# No     0.587539
# Yes    0.412461
# Name: package_transport_tz, dtype: float64
# --------- PACKAGE_SIGHTSEEING ---------
# No     0.690911
# Yes    0.309089
# Name: package_sightseeing, dtype: float64
# --------- PACKAGE_GUIDED_TOUR ---------
# No     0.672593
# Yes    0.327407
# Name: package_guided_tour, dtype: float64
# --------- PACKAGE_INSURANCE ---------
# No     0.854263
# Yes    0.145737
# Name: package_insurance, dtype: float64
# --------- NIGHT_MAINLAND ---------
# 0      0.126662
# 7      0.090673
# 4      0.072247
# 2      0.069923
# 3      0.069761
#          ...
# 182    0.000054
# 126    0.000054
# 118    0.000054
# 181    0.000054
# 92     0.000054
# Name: night_mainland, Length: 110, dtype: float64
# --------- NIGHT_ZANZIBAR ---------
# 0      0.625689
# 7      0.082838
# 4      0.055658
# 3      0.049768
# 5      0.043932
# 6      0.033719
# 2      0.023020
# 8      0.015346
# 10     0.013185
# 14     0.011672
# 9      0.009240
# 1      0.008214
# 12     0.004701
# 11     0.004215
# 15     0.003458
# 13     0.003350
# 20     0.001783
# 21     0.001405
# 17     0.001297
# 16     0.001027
# 30     0.000702
# 19     0.000702
# 18     0.000486
# 22     0.000432
# 28     0.000432
# 60     0.000324
# 23     0.000324
# 35     0.000324
# 25     0.000216
# 90     0.000216
# 27     0.000216
# 41     0.000162
# 33     0.000162
# 42     0.000108
# 51     0.000108
# 39     0.000108
# 44     0.000108
# 120    0.000108
# 40     0.000108
# 55     0.000054
# 43     0.000054
# 80     0.000054
# 70     0.000054
# 61     0.000054
# 46     0.000054
# 64     0.000054
# 50     0.000054
# 45     0.000054
# 108    0.000054
# 34     0.000054
# 26     0.000054
# 75     0.000054
# 240    0.000054
# 48     0.000054
# 86     0.000054
# 32     0.000054
# 100    0.000054
# 107    0.000054
# 87     0.000054
# 31     0.000054
# Name: night_zanzibar, dtype: float64
# --------- FIRST_TRIP_TZ ---------
# Yes    0.688263
# No     0.311737
# Name: first_trip_tz, dtype: float64
# --------- COST_CATEGORY ---------
# Normal Cost     0.295634
# Higher Cost     0.262888
# High Cost       0.198746
# Lower Cost      0.138712
# Low Cost        0.084621
# Highest Cost    0.019399
# Name: cost_category, dtype: float64

# %%
#Test Set
for column in test:
    print("---------",column.upper(),"---------")
    print(train[column].value_counts(normalize=True))
# Out:
# --------- COUNTRY ---------
# UNITED STATES OF AMERICA    0.153788
# UNITED KINGDOM              0.114557
# ITALY                       0.087809
# FRANCE                      0.057495
# GERMANY                     0.052361
#                               ...
# JORDAN                      0.000054
# BARBADOS                    0.000054
# BANGLADESH                  0.000054
# CAPE VERDE                  0.000054
# DJIBOUT                     0.000054
# Name: country, Length: 131, dtype: float64
# --------- AGE_GROUP ---------
# 25-44    0.488868
# 45-64    0.305198
# 18-24    0.120069
# 65+      0.079272
# <18      0.006592
# Name: age_group, dtype: float64
# --------- TRAVEL_WITH ---------
# Alone                           0.435431
# With Spouse                     0.277781
# With Other Friends/Relatives    0.187482
# With Spouse and Children        0.068441
# With Children                   0.030865
# Name: travel_with, dtype: float64
# --------- TOTAL_FEMALE ---------
# 1.0     0.521995
# 0.0     0.332198
# 2.0     0.094682
# 3.0     0.027399
# 4.0     0.010592
# 5.0     0.004810
# 6.0     0.003243
# 7.0     0.000973
# 8.0     0.000919
# 10.0    0.000703
# 11.0    0.000486
# 9.0     0.000432
# 12.0    0.000432
# 14.0    0.000324
# 13.0    0.000162
# 15.0    0.000162
# 24.0    0.000108
# 22.0    0.000054
# 17.0    0.000054
# 26.0    0.000054
# 20.0    0.000054
# 49.0    0.000054
# 23.0    0.000054
# 19.0    0.000054
# Name: total_female, dtype: float64
# --------- TOTAL_MALE ---------
# 1.0     0.638270
# 0.0     0.234270
# 2.0     0.081135
# 3.0     0.027568
# 4.0     0.008054
# 5.0     0.003622
# 6.0     0.002973
# 7.0     0.001243
# 8.0     0.000649
# 9.0     0.000486
# 10.0    0.000486
# 13.0    0.000216
# 15.0    0.000162
# 12.0    0.000162
# 11.0    0.000162
# 17.0    0.000108
# 20.0    0.000054
# 23.0    0.000054
# 44.0    0.000054
# 40.0    0.000054
# 24.0    0.000054
# 25.0    0.000054
# 14.0    0.000054
# 58.0    0.000054
# Name: total_male, dtype: float64
# --------- PURPOSE ---------
# Leisure and Holidays              0.635199
# Visiting Friends and Relatives    0.124500
# Business                          0.124122
# Meetings and Conference           0.063709
# Volunteering                      0.023668
# Other                             0.017616
# Scientific and Academic           0.010699
# Medical                           0.000486
# Name: purpose, dtype: float64
# --------- MAIN_ACTIVITY ---------
# Widlife Tourism             0.323571
# Beach Tourism               0.225440
# Wildlife Tourism            0.123365
# Conference Tourism          0.103750
# Hunting Tourism             0.092511
# Cultural Tourism            0.078029
# Mountain Climbing           0.028585
# Business                    0.015130
# Bird Tourism                0.007781
# Diving and Sport Fishing    0.001837
# Name: main_activity, dtype: float64
# --------- INFO_SOURCE ---------
# Travel agent, tour operator        0.432562
# Friends, relatives                 0.328380
# Others                             0.073922
# Newspaper, magazines, brochures    0.070302
# Radio, TV, Web                     0.066087
# Trade fair                         0.013131
# Tanzania Mission Abroad            0.010645
# Inflight magazines                 0.004971
# Name: info_source, dtype: float64
# --------- TOUR_ARRANGEMENT ---------
# Package Tour    0.50227
# Independent     0.49773
# Name: tour_arrangement, dtype: float64
# --------- PACKAGE_TRANSPORT_INT ---------
# No     0.661299
# Yes    0.338701
# Name: package_transport_int, dtype: float64
# --------- PACKAGE_ACCOMODATION ---------
# No     0.515563
# Yes    0.484437
# Name: package_accomodation, dtype: float64
# --------- PACKAGE_FOOD ---------
# No     0.548093
# Yes    0.451907
# Name: package_food, dtype: float64
# --------- PACKAGE_TRANSPORT_TZ ---------
# No     0.587539
# Yes    0.412461
# Name: package_transport_tz, dtype: float64
# --------- PACKAGE_SIGHTSEEING ---------
# No     0.690911
# Yes    0.309089
# Name: package_sightseeing, dtype: float64
# --------- PACKAGE_GUIDED_TOUR ---------
# No     0.672593
# Yes    0.327407
# Name: package_guided_tour, dtype: float64
# --------- PACKAGE_INSURANCE ---------
# No     0.854263
# Yes    0.145737
# Name: package_insurance, dtype: float64
# --------- NIGHT_MAINLAND ---------
# 0      0.126662
# 7      0.090673
# 4      0.072247
# 2      0.069923
# 3      0.069761
#          ...
# 182    0.000054
# 126    0.000054
# 118    0.000054
# 181    0.000054
# 92     0.000054
# Name: night_mainland, Length: 110, dtype: float64
# --------- NIGHT_ZANZIBAR ---------
# 0      0.625689
# 7      0.082838
# 4      0.055658
# 3      0.049768
# 5      0.043932
# 6      0.033719
# 2      0.023020
# 8      0.015346
# 10     0.013185
# 14     0.011672
# 9      0.009240
# 1      0.008214
# 12     0.004701
# 11     0.004215
# 15     0.003458
# 13     0.003350
# 20     0.001783
# 21     0.001405
# 17     0.001297
# 16     0.001027
# 30     0.000702
# 19     0.000702
# 18     0.000486
# 22     0.000432
# 28     0.000432
# 60     0.000324
# 23     0.000324
# 35     0.000324
# 25     0.000216
# 90     0.000216
# 27     0.000216
# 41     0.000162
# 33     0.000162
# 42     0.000108
# 51     0.000108
# 39     0.000108
# 44     0.000108
# 120    0.000108
# 40     0.000108
# 55     0.000054
# 43     0.000054
# 80     0.000054
# 70     0.000054
# 61     0.000054
# 46     0.000054
# 64     0.000054
# 50     0.000054
# 45     0.000054
# 108    0.000054
# 34     0.000054
# 26     0.000054
# 75     0.000054
# 240    0.000054
# 48     0.000054
# 86     0.000054
# 32     0.000054
# 100    0.000054
# 107    0.000054
# 87     0.000054
# 31     0.000054
# Name: night_zanzibar, dtype: float64
# --------- FIRST_TRIP_TZ ---------
# Yes    0.688263
# No     0.311737
# Name: first_trip_tz, dtype: float64

# %%
#Frequency distribution for cost types
sns.displot(
    train['cost_category'],
    aspect=1.5
)

# %% [markdown]
# Good news - **train and test set distributions are ostensibly the same**! So it stands to reason that if we do well on the training set, the transition to the test set should be pretty smooth too.
#
# -> Most of the people fall into the normal cost/higher cost category, so might be worth focusing our efforts on making sure that predictions for those groups are best, at least to start with.

# %%
#Find missing data
print("Training set missing: ")
print(train.isna().sum()/train.shape[0])
print("----------------------")
print("Test set missing: ")
print(test.isna().sum()/train.shape[0])
# Out:
# Training set missing:
# country                  0.000000
# age_group                0.000000
# travel_with              0.058089
# total_female             0.000108
# total_male               0.000324
# purpose                  0.000000
# main_activity            0.000000
# info_source              0.000000
# tour_arrangement         0.000000
# package_transport_int    0.000000
# package_accomodation     0.000000
# package_food             0.000000
# package_transport_tz     0.000000
# package_sightseeing      0.000000
# package_guided_tour      0.000000
# package_insurance        0.000000
# night_mainland           0.000000
# night_zanzibar           0.000000
# first_trip_tz            0.000000
# cost_category            0.000000
# dtype: float64
# ----------------------
# Test set missing:
# country                  0.000000
# age_group                0.000000
# travel_with              0.019507
# total_female             0.000108
# total_male               0.000054
# purpose                  0.000000
# main_activity            0.000000
# info_source              0.000000
# tour_arrangement         0.000000
# package_transport_int    0.000000
# package_accomodation     0.000000
# package_food             0.000000
# package_transport_tz     0.000000
# package_sightseeing      0.000000
# package_guided_tour      0.000000
# package_insurance        0.000000
# night_mainland           0.000000
# night_zanzibar           0.000000
# first_trip_tz            0.000000
# dtype: float64

# %% [markdown]
# Missing data mostly comes from travel_with, total_male, and total_female. But definitely not a significant amount - maybe just a handful fo entries in each one. Will not affect performance too much, but we may still want to look into it.

# %% [markdown]
# ### Relationships
#
# Seeing correlates may help inform development of ML model, so a pair plot might help. *NB: This only helps visualize relationships between floating point variables i.e. will not help with categorical variables.*

# %%
sns.pairplot(train) # computationally expensive - try to just run once!

# %%
correlations = train.corr()
sns.heatmap(correlations, cmap="vlag", vmin=-1, vmax=1)
# Out:
# /var/folders/46/3phyn9592wj1fgj0kywgvld00000gq/T/ipykernel_28890/3462160808.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlations = train.corr()
# <Axes: >

# %% [markdown]
# Now we do the same, but with categorical variables and crosstab:

# %%
tmp = pd.crosstab(train.cost_category, train.info_source)
sns.heatmap(tmp)
# Out:
# <Axes: xlabel='info_source', ylabel='cost_category'>

# %%
tmp = pd.crosstab(train.cost_category, train.tour_arrangement)
sns.heatmap(tmp)
# Out:
# <Axes: xlabel='tour_arrangement', ylabel='cost_category'>

# %%
tmp = pd.crosstab(train.cost_category, train.first_trip_tz)
sns.heatmap(tmp)
# Out:
# <Axes: xlabel='first_trip_tz', ylabel='cost_category'>

# %%
train.groupby('cost_category').night_mainland.mean()
# Out:
# cost_category
# High Cost        9.113105
# Higher Cost      9.026516
# Highest Cost     7.699164
# Low Cost         8.454023
# Lower Cost       6.733541
# Normal Cost     10.684336
# Name: night_mainland, dtype: float64

# %%
train.groupby('cost_category').night_zanzibar.mean()
# Out:
# cost_category
# High Cost       3.617455
# Higher Cost     3.310997
# Highest Cost    2.949861
# Low Cost        1.101533
# Lower Cost      0.431243
# Normal Cost     2.347103
# Name: night_zanzibar, dtype: float64

# %% [markdown]
# So, some patterns noticed from the data:
#
# -> Use of a travel agent/tour operator is correlated with higher spending. Also, to some extent, friends and relatives recommendations generally correlated with Normal cost category.
#
# -> Independent tour arrangements correlated with Low to Normal spending, Package tour arrangement correlated with High spending.
#
# -> First time travellers to Tanzania tended to spend more
#
# -> Nights spent in mainland don't have a significant bearing on spending categories
#
# -> Night spent in Zanzibar have a good correlation with spending categories
